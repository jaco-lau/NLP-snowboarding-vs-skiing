# %% [markdown]
# ### Subreddits
# https://www.reddit.com/r/snowboarding/
#
# https://www.reddit.com/r/skiing/

# %% [markdown]
# #### api links
# api.pushshift.io/reddit/search/?subreddit=snowboarding
#
# http://api.pushshift.io/reddit/comment/search/?subreddit=skiing
#
# https://github.com/pushshift/api
#
# parameters: https://pushshift.io/api-parameters/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# Thanks to Hov, he inspired me to create a separate notebook that contained
# my functions so I could import them instead of having them take up so much 
# space
from functions import cvec_df,ski_and_sb_stopword_list,model_confusion_matrix

# %%
np.random.seed(42)

# %% [markdown]
# ## Import Comments

# %%
# import data
sb_v_ski = pd.read_csv('./data/all_comment_data_2500.csv',index_col = 0)
sb = pd.read_csv('./data/sb_comment_data_2500.csv',index_col = 0)
ski = pd.read_csv('./data/ski_comment_data_2500.csv',index_col = 0)

# %%
pd.set_option('display.max_columns',100)

# %% [markdown]
# ## Stop Word Lists

# %%
# instantiate stopwordlist
stop_words_list = ski_and_sb_stopword_list()

# %% [markdown]
# ## Count Vectorizing

# %%
# CountVectorize all comments
comment_df = cvec_df(sb_v_ski,'stemmed comments',stop_words_list)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
# analyze top 15 words
comment_df.sum().sort_values(ascending = False).head(25).plot(kind = 'barh', title = 'top 15 words')

plt.gca().invert_yaxis();

# %% [markdown]
# ### Ski Count Vectorizer

# %%
# CountVectorize skiing comments
ski_comment_df = cvec_df(ski,'stemmed comments',stop_words_list)

# %%
# analyze top 15 words from skiing comments
ski_comment_df.sum().sort_values(ascending = False).head(25).plot(kind = 'barh', title = 'top 15 words')

plt.gca().invert_yaxis();

# %% [markdown]
# ### Snowboarding Count Vectorizer

# %%
# CountVectorize snowboarding comments
sb_comment_df = cvec_df(sb,'stemmed comments',stop_words_list)

# %%
# analyze top 15 words from snowboarding comments
sb_comment_df.sum().sort_values(ascending = False).head(20).plot(kind = 'barh', title = 'top 15 words')

plt.gca().invert_yaxis();

# %% [markdown]
# ## Model Set Up

# %% [markdown]
# Due to Gridsearch automatically train test splitting data by using cross validation, there is no need so train test split the X and y variables.
#
# Additionally, baseline accuracy is 50% since the classes are perfectly balanced.

# %%
# set feature (X) and target (y) variables
X = sb_v_ski['stemmed comments']

y = sb_v_ski['ski or sb']

# %% [markdown]
# ## Naive Bayes
# ### Count Vectorizer

# %%
# set up Pipeline
nb_pipe = Pipeline([
    ('cvec', CountVectorizer(stop_words = stop_words_list)),
    ('nb', MultinomialNB())
])

# %%
# set parameters
nb_pipe_params = {
    'cvec__max_features': [5000],
    'cvec__min_df': [.01,.025,.03,.05],
    'cvec__max_df': [.95],
    'cvec__ngram_range': [(1,1),(1,2),(2,2),(3,3),(1,3)],
    'nb__alpha': [0,1]
}

# %%
# set up GridSearch
nb_cvec = GridSearchCV(
    estimator = nb_pipe,
    param_grid = nb_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
nb_cvec.fit(X,y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   10.1s finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py:511: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn('alpha too small will result in numeric errors, '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('cvec',
#                                         CountVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biathalon',
#                                                                     'snowcross',
#                                                                     'surfing',
#                                                                     'apres-ski',
#                                                                     'nordic '
#                                                                     'combined', ...])),
#                                        ('nb', MultinomialNB())]),
#              n_jobs=8,
#              param_grid={'cvec__max_df': [0.95], 'cvec__max_features': [5000],
#                          'cvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'cvec__ngram_range': [(1, 1), (1, 2), (2, 2), (3, 3),
#                                                (1, 3)],
#                          'nb__alpha': [0, 1]},
#              verbose=1)

# %%
# look at best parameters
nb_cvec.best_params_
# Out:
# {'cvec__max_df': 0.95,
#  'cvec__max_features': 5000,
#  'cvec__min_df': 0.01,
#  'cvec__ngram_range': (1, 3),
#  'nb__alpha': 0}

# %%
# look at best scores
nb_cvec.best_score_
# Out:
# 0.8789999999999999

# %%
# Thanks to Hov I was able to learn about .cv_results_ (I was running a ton
# of different gridsearches prior to that)
nb_cvec_results = pd.DataFrame(nb_cvec.cv_results_)

# %%
# look at GridSearch results
nb_cvec_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.147273      0.008115         0.033251        0.003233
# 1        0.145855      0.011716         0.030467        0.001766
# 2        0.281233      0.004936         0.059556        0.004950
# 3        0.313484      0.024962         0.066777        0.010644
# 4        0.258406      0.019948         0.065229        0.007458
# 5        0.269361      0.005179         0.060434        0.003698
# 6        0.263750      0.006606         0.057876        0.005964
# 7        0.261862      0.008731         0.060029        0.006555
# 8        0.481337      0.011412         0.101223        0.006127
# 9        0.484218      0.011868         0.102208        0.013471
# 10       0.171350      0.003718         0.043812        0.003723
# 11       0.171742      0.006435         0.047306        0.010688
# 12       0.335477      0.009261         0.063017        0.010716
# 13       0.325463      0.016733         0.066111        0.008345
# 14       0.248562      0.007603         0.051275        0.006534
# 15       0.240964      0.007022         0.058805        0.012738
# 16       0.254078      0.030026         0.000000        0.000000
# 17       0.268008      0.012406         0.000000        0.000000
# 18       0.483205      0.007877         0.092891        0.005339
# 19       0.506323      0.025169         0.093999        0.012977
# 20       0.214289      0.006788         0.038922        0.005824
# 21       0.163085      0.021439         0.034195        0.005017
# 22       0.298667      0.007219         0.064205        0.003468
# 23       0.307294      0.005341         0.065809        0.004920
# 24       0.225320      0.007917         0.043410        0.005765
# 25       0.204294      0.007878         0.040684        0.002736
# 26       0.188899      0.006439         0.000000        0.000000
# 27       0.182118      0.008259         0.000000        0.000000
# 28       0.394671      0.023256         0.082170        0.009569
# 29       0.427138      0.037000         0.091204        0.003150
# 30       0.155908      0.007713         0.031854        0.001187
# 31       0.167076      0.011160         0.035195        0.003390
# 32       0.306786      0.007771         0.057182        0.003248
# 33       0.286836      0.009722         0.062917        0.004578
# 34       0.219722      0.006178         0.000000        0.000000
# 35       0.209082      0.006032         0.000000        0.000000
# 36       0.203726      0.003749         0.000000        0.000000
# 37       0.201377      0.006316         0.000000        0.000000
# 38       0.388606      0.012325         0.074078        0.002128
# 39       0.339958      0.054601         0.056492        0.017410
#
#    param_cvec__max_df param_cvec__max_features param_cvec__min_df  \
# 0                0.95                     5000               0.01
# 1                0.95                     5000               0.01
# 2                0.95                     5000               0.01
# 3                0.95                     5000               0.01
# 4                0.95                     5000               0.01
# 5                0.95                     5000               0.01
# 6                0.95                     5000               0.01
# 7                0.95                     5000               0.01
# 8                0.95                     5000               0.01
# 9                0.95                     5000               0.01
# 10               0.95                     5000              0.025
# 11               0.95                     5000              0.025
# 12               0.95                     5000              0.025
# 13               0.95                     5000              0.025
# 14               0.95                     5000              0.025
# 15               0.95                     5000              0.025
# 16               0.95                     5000              0.025
# 17               0.95                     5000              0.025
# 18               0.95                     5000              0.025
# 19               0.95                     5000              0.025
# 20               0.95                     5000               0.03
# 21               0.95                     5000               0.03
# 22               0.95                     5000               0.03
# 23               0.95                     5000               0.03
# 24               0.95                     5000               0.03
# 25               0.95                     5000               0.03
# 26               0.95                     5000               0.03
# 27               0.95                     5000               0.03
# 28               0.95                     5000               0.03
# 29               0.95                     5000               0.03
# 30               0.95                     5000               0.05
# 31               0.95                     5000               0.05
# 32               0.95                     5000               0.05
# 33               0.95                     5000               0.05
# 34               0.95                     5000               0.05
# 35               0.95                     5000               0.05
# 36               0.95                     5000               0.05
# 37               0.95                     5000               0.05
# 38               0.95                     5000               0.05
# 39               0.95                     5000               0.05
#
#    param_cvec__ngram_range param_nb__alpha  \
# 0                   (1, 1)               0
# 1                   (1, 1)               1
# 2                   (1, 2)               0
# 3                   (1, 2)               1
# 4                   (2, 2)               0
# 5                   (2, 2)               1
# 6                   (3, 3)               0
# 7                   (3, 3)               1
# 8                   (1, 3)               0
# 9                   (1, 3)               1
# 10                  (1, 1)               0
# 11                  (1, 1)               1
# 12                  (1, 2)               0
# 13                  (1, 2)               1
# 14                  (2, 2)               0
# 15                  (2, 2)               1
# 16                  (3, 3)               0
# 17                  (3, 3)               1
# 18                  (1, 3)               0
# 19                  (1, 3)               1
# 20                  (1, 1)               0
# 21                  (1, 1)               1
# 22                  (1, 2)               0
# 23                  (1, 2)               1
# 24                  (2, 2)               0
# 25                  (2, 2)               1
# 26                  (3, 3)               0
# 27                  (3, 3)               1
# 28                  (1, 3)               0
# 29                  (1, 3)               1
# 30                  (1, 1)               0
# 31                  (1, 1)               1
# 32                  (1, 2)               0
# 33                  (1, 2)               1
# 34                  (2, 2)               0
# 35                  (2, 2)               1
# 36                  (3, 3)               0
# 37                  (3, 3)               1
# 38                  (1, 3)               0
# 39                  (1, 3)               1
#
#                                                params  split0_test_score  \
# 0   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.785
# 1   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.786
# 2   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.863
# 3   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.841
# 4   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.523
# 5   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.526
# 6   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.500
# 7   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.478
# 8   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.869
# 9   {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.849
# 10  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.636
# 11  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.636
# 12  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.637
# 13  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.637
# 14  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.491
# 15  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.491
# 16  {'cvec__max_df': 0.95, 'cvec__max_features': 5...                NaN
# 17  {'cvec__max_df': 0.95, 'cvec__max_features': 5...                NaN
# 18  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.637
# 19  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.637
# 20  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.637
# 21  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.637
# 22  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.636
# 23  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.637
# 24  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.500
# 25  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.500
# 26  {'cvec__max_df': 0.95, 'cvec__max_features': 5...                NaN
# 27  {'cvec__max_df': 0.95, 'cvec__max_features': 5...                NaN
# 28  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.636
# 29  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.637
# 30  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.581
# 31  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.581
# 32  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.581
# 33  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.581
# 34  {'cvec__max_df': 0.95, 'cvec__max_features': 5...                NaN
# 35  {'cvec__max_df': 0.95, 'cvec__max_features': 5...                NaN
# 36  {'cvec__max_df': 0.95, 'cvec__max_features': 5...                NaN
# 37  {'cvec__max_df': 0.95, 'cvec__max_features': 5...                NaN
# 38  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.581
# 39  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.581
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0               0.774              0.787              0.813
# 1               0.776              0.787              0.816
# 2               0.870              0.876              0.883
# 3               0.851              0.860              0.864
# 4               0.530              0.526              0.525
# 5               0.509              0.507              0.461
# 6               0.500              0.500              0.501
# 7               0.412              0.214              0.260
# 8               0.873              0.880              0.893
# 9               0.855              0.863              0.872
# 10              0.661              0.620              0.707
# 11              0.639              0.620              0.707
# 12              0.660              0.619              0.706
# 13              0.638              0.620              0.707
# 14              0.490              0.491              0.494
# 15              0.490              0.491              0.494
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18              0.660              0.619              0.706
# 19              0.638              0.620              0.707
# 20              0.620              0.657              0.647
# 21              0.620              0.657              0.648
# 22              0.619              0.656              0.647
# 23              0.619              0.657              0.646
# 24              0.500              0.500              0.500
# 25              0.500              0.500              0.500
# 26                NaN                NaN                NaN
# 27                NaN                NaN                NaN
# 28              0.619              0.656              0.647
# 29              0.619              0.657              0.646
# 30              0.579              0.574              0.585
# 31              0.579              0.574              0.585
# 32              0.579              0.574              0.585
# 33              0.579              0.574              0.585
# 34                NaN                NaN                NaN
# 35                NaN                NaN                NaN
# 36                NaN                NaN                NaN
# 37                NaN                NaN                NaN
# 38              0.579              0.574              0.585
# 39              0.579              0.574              0.585
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0               0.812           0.7942        0.015587                6
# 1               0.813           0.7956        0.015932                5
# 2               0.874           0.8732        0.006615                2
# 3               0.854           0.8540        0.007925                4
# 4               0.522           0.5252        0.002786               25
# 5               0.481           0.4968        0.022964               29
# 6               0.501           0.5004        0.000490               26
# 7               0.153           0.3034        0.122291               32
# 8               0.880           0.8790        0.008173                1
# 9               0.861           0.8600        0.007746                3
# 10              0.647           0.6542        0.029620                9
# 11              0.648           0.6500        0.029900               12
# 12              0.690           0.6624        0.032240                7
# 13              0.650           0.6504        0.029870               10
# 14              0.493           0.4918        0.001470               30
# 15              0.493           0.4918        0.001470               30
# 16                NaN              NaN             NaN               35
# 17                NaN              NaN             NaN               34
# 18              0.690           0.6624        0.032240                7
# 19              0.650           0.6504        0.029870               10
# 20              0.651           0.6424        0.012955               14
# 21              0.651           0.6426        0.013032               13
# 22              0.651           0.6418        0.013167               17
# 23              0.652           0.6422        0.013378               15
# 24              0.500           0.5000        0.000000               27
# 25              0.500           0.5000        0.000000               27
# 26                NaN              NaN             NaN               40
# 27                NaN              NaN             NaN               33
# 28              0.651           0.6418        0.013167               17
# 29              0.652           0.6422        0.013378               15
# 30              0.597           0.5832        0.007756               19
# 31              0.597           0.5832        0.007756               19
# 32              0.597           0.5832        0.007756               19
# 33              0.597           0.5832        0.007756               19
# 34                NaN              NaN             NaN               36
# 35                NaN              NaN             NaN               37
# 36                NaN              NaN             NaN               38
# 37                NaN              NaN             NaN               39
# 38              0.597           0.5832        0.007756               19
# 39              0.597           0.5832        0.007756               19

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
nb_cvec_results.groupby(['param_cvec__min_df'])['mean_test_score'].max()
# Out:
# param_cvec__min_df
# 0.010    0.8790
# 0.025    0.6624
# 0.030    0.6426
# 0.050    0.5832
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ### TFIDF Vectorizer

# %%
# set up Pipeline
nb2_pipe = Pipeline([
    ('tvec', TfidfVectorizer(stop_words = stop_words_list)),
    ('nb', MultinomialNB())
])

# %%
# set parameters
nb2_pipe_params = {
    'tvec__max_features': [5000],
    'tvec__min_df': [.01,.025,.03,.05],
    'tvec__max_df': [.95],
    'tvec__ngram_range': [(1,1),(1,2),(2,2),(3,3),(1,3)],
    'nb__alpha': [0,1]
}

# %%
# set up GridSearch
nb_tvec = GridSearchCV(
    estimator = nb2_pipe,
    param_grid = nb2_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
nb_tvec.fit(X,y)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 200 out of 200 | elapsed:   12.3s finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tvec',
#                                         TfidfVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biathalon',
#                                                                     'snowcross',
#                                                                     'surfing',
#                                                                     'apres-ski',
#                                                                     'nordic '
#                                                                     'combined', ...])),
#                                        ('nb', MultinomialNB())]),
#              n_jobs=8,
#              param_grid={'nb__alpha': [0, 1], 'tvec__max_df': [0.95],
#                          'tvec__max_features': [5000],
#                          'tvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'tvec__ngram_range': [(1, 1), (1, 2), (2, 2), (3, 3),
#                                                (1, 3)]},
#              verbose=1)

# %%
# look at best parameters
nb_tvec.best_params_
# Out:
# {'nb__alpha': 1,
#  'tvec__max_df': 0.95,
#  'tvec__max_features': 5000,
#  'tvec__min_df': 0.01,
#  'tvec__ngram_range': (1, 3)}

# %%
# look at best scores
nb_tvec.best_score_
# Out:
# 0.9216000000000001

# %%
# turn results into a dataframe
nb_tvec_results = pd.DataFrame(nb_tvec.cv_results_)

# %%
# look at GridSearch results
nb_tvec_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.135295      0.012965         0.036880        0.004470
# 1        0.298119      0.002725         0.064128        0.003269
# 2        0.221874      0.007063         0.051228        0.005133
# 3        0.222654      0.014473         0.050023        0.002644
# 4        0.518798      0.118573         0.105349        0.036120
# 5        0.152798      0.017943         0.039319        0.006980
# 6        0.434748      0.083384         0.097946        0.021264
# 7        0.360812      0.041374         0.103197        0.025947
# 8        0.379651      0.032266         0.000000        0.000000
# 9        0.751163      0.019903         0.144781        0.005816
# 10       0.264135      0.018330         0.060074        0.010501
# 11       0.501667      0.018062         0.104553        0.020334
# 12       0.381064      0.025275         0.095726        0.012904
# 13       0.346847      0.014478         0.000000        0.000000
# 14       0.654274      0.043960         0.121537        0.015050
# 15       0.233683      0.021495         0.046987        0.006892
# 16       0.426460      0.023847         0.093961        0.006942
# 17       0.335953      0.038465         0.000000        0.000000
# 18       0.335067      0.020564         0.000000        0.000000
# 19       0.636464      0.030134         0.120762        0.014060
# 20       0.212254      0.015900         0.056744        0.012187
# 21       0.463842      0.021262         0.111882        0.007599
# 22       0.351000      0.023521         0.067902        0.008267
# 23       0.363399      0.008564         0.072392        0.004395
# 24       0.687369      0.028503         0.155629        0.013964
# 25       0.246999      0.016445         0.060182        0.011439
# 26       0.466389      0.037361         0.101914        0.009063
# 27       0.346421      0.029199         0.081525        0.008635
# 28       0.346356      0.010826         0.000000        0.000000
# 29       0.647290      0.010710         0.127658        0.013908
# 30       0.232004      0.014247         0.054320        0.006659
# 31       0.474738      0.019385         0.123233        0.023590
# 32       0.400545      0.019906         0.092078        0.021330
# 33       0.323898      0.020719         0.000000        0.000000
# 34       0.636414      0.022034         0.137505        0.017565
# 35       0.213408      0.017102         0.059464        0.013512
# 36       0.543402      0.039416         0.164726        0.027483
# 37       0.438154      0.006032         0.000000        0.000000
# 38       0.363763      0.041666         0.000000        0.000000
# 39       0.576115      0.028907         0.081280        0.033840
#
#    param_nb__alpha param_tvec__max_df param_tvec__max_features  \
# 0                0               0.95                     5000
# 1                0               0.95                     5000
# 2                0               0.95                     5000
# 3                0               0.95                     5000
# 4                0               0.95                     5000
# 5                0               0.95                     5000
# 6                0               0.95                     5000
# 7                0               0.95                     5000
# 8                0               0.95                     5000
# 9                0               0.95                     5000
# 10               0               0.95                     5000
# 11               0               0.95                     5000
# 12               0               0.95                     5000
# 13               0               0.95                     5000
# 14               0               0.95                     5000
# 15               0               0.95                     5000
# 16               0               0.95                     5000
# 17               0               0.95                     5000
# 18               0               0.95                     5000
# 19               0               0.95                     5000
# 20               1               0.95                     5000
# 21               1               0.95                     5000
# 22               1               0.95                     5000
# 23               1               0.95                     5000
# 24               1               0.95                     5000
# 25               1               0.95                     5000
# 26               1               0.95                     5000
# 27               1               0.95                     5000
# 28               1               0.95                     5000
# 29               1               0.95                     5000
# 30               1               0.95                     5000
# 31               1               0.95                     5000
# 32               1               0.95                     5000
# 33               1               0.95                     5000
# 34               1               0.95                     5000
# 35               1               0.95                     5000
# 36               1               0.95                     5000
# 37               1               0.95                     5000
# 38               1               0.95                     5000
# 39               1               0.95                     5000
#
#    param_tvec__min_df param_tvec__ngram_range  \
# 0                0.01                  (1, 1)
# 1                0.01                  (1, 2)
# 2                0.01                  (2, 2)
# 3                0.01                  (3, 3)
# 4                0.01                  (1, 3)
# 5               0.025                  (1, 1)
# 6               0.025                  (1, 2)
# 7               0.025                  (2, 2)
# 8               0.025                  (3, 3)
# 9               0.025                  (1, 3)
# 10               0.03                  (1, 1)
# 11               0.03                  (1, 2)
# 12               0.03                  (2, 2)
# 13               0.03                  (3, 3)
# 14               0.03                  (1, 3)
# 15               0.05                  (1, 1)
# 16               0.05                  (1, 2)
# 17               0.05                  (2, 2)
# 18               0.05                  (3, 3)
# 19               0.05                  (1, 3)
# 20               0.01                  (1, 1)
# 21               0.01                  (1, 2)
# 22               0.01                  (2, 2)
# 23               0.01                  (3, 3)
# 24               0.01                  (1, 3)
# 25              0.025                  (1, 1)
# 26              0.025                  (1, 2)
# 27              0.025                  (2, 2)
# 28              0.025                  (3, 3)
# 29              0.025                  (1, 3)
# 30               0.03                  (1, 1)
# 31               0.03                  (1, 2)
# 32               0.03                  (2, 2)
# 33               0.03                  (3, 3)
# 34               0.03                  (1, 3)
# 35               0.05                  (1, 1)
# 36               0.05                  (1, 2)
# 37               0.05                  (2, 2)
# 38               0.05                  (3, 3)
# 39               0.05                  (1, 3)
#
#                                                params  split0_test_score  \
# 0   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.869
# 1   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.899
# 2   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.523
# 3   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.500
# 4   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.909
# 5   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.781
# 6   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.781
# 7   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.491
# 8   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...                NaN
# 9   {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.781
# 10  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.743
# 11  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.744
# 12  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.500
# 13  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...                NaN
# 14  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.744
# 15  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.656
# 16  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.656
# 17  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...                NaN
# 18  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...                NaN
# 19  {'nb__alpha': 0, 'tvec__max_df': 0.95, 'tvec__...              0.656
# 20  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.871
# 21  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.901
# 22  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.461
# 23  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.434
# 24  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.910
# 25  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.780
# 26  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.780
# 27  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.491
# 28  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...                NaN
# 29  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.780
# 30  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.745
# 31  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.745
# 32  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.500
# 33  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...                NaN
# 34  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.745
# 35  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.656
# 36  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.656
# 37  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...                NaN
# 38  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...                NaN
# 39  {'nb__alpha': 1, 'tvec__max_df': 0.95, 'tvec__...              0.656
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0               0.889              0.896              0.894
# 1               0.907              0.917              0.928
# 2               0.529              0.526              0.525
# 3               0.500              0.500              0.501
# 4               0.913              0.923              0.931
# 5               0.795              0.802              0.794
# 6               0.793              0.804              0.793
# 7               0.490              0.491              0.494
# 8                 NaN                NaN                NaN
# 9               0.793              0.804              0.793
# 10              0.742              0.760              0.754
# 11              0.742              0.759              0.754
# 12              0.500              0.500              0.500
# 13                NaN                NaN                NaN
# 14              0.742              0.759              0.754
# 15              0.613              0.629              0.654
# 16              0.613              0.629              0.654
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19              0.613              0.629              0.654
# 20              0.890              0.898              0.900
# 21              0.908              0.922              0.932
# 22              0.467              0.466              0.464
# 23              0.434              0.436              0.436
# 24              0.912              0.926              0.934
# 25              0.794              0.807              0.794
# 26              0.795              0.806              0.794
# 27              0.490              0.491              0.494
# 28                NaN                NaN                NaN
# 29              0.795              0.806              0.794
# 30              0.743              0.761              0.755
# 31              0.744              0.760              0.754
# 32              0.500              0.500              0.500
# 33                NaN                NaN                NaN
# 34              0.744              0.760              0.754
# 35              0.613              0.607              0.654
# 36              0.613              0.607              0.654
# 37                NaN                NaN                NaN
# 38                NaN                NaN                NaN
# 39              0.613              0.607              0.654
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0               0.896           0.8888        0.010225                6
# 1               0.916           0.9134        0.009810                4
# 2               0.522           0.5250        0.002449               25
# 3               0.501           0.5004        0.000490               26
# 4               0.921           0.9194        0.007736                2
# 5               0.789           0.7922        0.006969               10
# 6               0.790           0.7922        0.007359               10
# 7               0.493           0.4918        0.001470               29
# 8                 NaN              NaN             NaN               40
# 9               0.790           0.7922        0.007359               10
# 10              0.754           0.7506        0.006974               18
# 11              0.756           0.7510        0.006753               16
# 12              0.500           0.5000        0.000000               27
# 13                NaN              NaN             NaN               37
# 14              0.756           0.7510        0.006753               16
# 15              0.611           0.6326        0.019335               19
# 16              0.611           0.6326        0.019335               19
# 17                NaN              NaN             NaN               38
# 18                NaN              NaN             NaN               35
# 19              0.611           0.6326        0.019335               19
# 20              0.896           0.8910        0.010545                5
# 21              0.918           0.9162        0.010815                3
# 22              0.461           0.4638        0.002482               31
# 23              0.435           0.4350        0.000894               32
# 24              0.926           0.9216        0.009156                1
# 25              0.788           0.7926        0.008845                9
# 26              0.790           0.7930        0.008390                7
# 27              0.493           0.4918        0.001470               29
# 28                NaN              NaN             NaN               36
# 29              0.790           0.7930        0.008390                7
# 30              0.754           0.7516        0.006681               15
# 31              0.756           0.7518        0.006274               13
# 32              0.500           0.5000        0.000000               27
# 33                NaN              NaN             NaN               39
# 34              0.756           0.7518        0.006274               13
# 35              0.613           0.6286        0.021676               22
# 36              0.613           0.6286        0.021676               22
# 37                NaN              NaN             NaN               33
# 38                NaN              NaN             NaN               34
# 39              0.613           0.6286        0.021676               22

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
nb_tvec_results.groupby(['param_tvec__min_df'])['mean_test_score'].max()
# Out:
# param_tvec__min_df
# 0.010    0.9216
# 0.025    0.7930
# 0.030    0.7518
# 0.050    0.6326
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ## Random Forest
# ### Count Vectorizer

# %%
# set up Pipeline
rf_pipe = Pipeline([
    ('cvec', CountVectorizer(stop_words = stop_words_list)),
    ('rf', RandomForestClassifier())
])

# %%
# set parameters
rf_pipe_params = {
    'cvec__max_features': [2000,3000,4000,5000],
    'cvec__min_df': [.01,.025,.03,.05],
    'cvec__max_df': [.9,.95],
    'cvec__ngram_range': [(1,1),(1,2),(1,3)],
    'rf__n_estimators': [1,10,100,150],
    'rf__max_depth': [2,3],
    'rf__min_samples_split' : [5,10],
    'rf__min_samples_leaf' : [2,3],
}

# %%
# set up GridSearch
rf_cvec = GridSearchCV(
    estimator = rf_pipe,
    param_grid = rf_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
rf_cvec.fit(X,y)
# Out:
# Fitting 5 folds for each of 3072 candidates, totalling 15360 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=8)]: Done 1234 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=8)]: Done 1784 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=8)]: Done 2434 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=8)]: Done 3184 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=8)]: Done 4034 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=8)]: Done 4984 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=8)]: Done 6034 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=8)]: Done 7184 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=8)]: Done 8434 tasks      | elapsed: 25.1min
# [Parallel(n_jobs=8)]: Done 9784 tasks      | elapsed: 28.4min
# [Parallel(n_jobs=8)]: Done 11234 tasks      | elapsed: 32.0min
# [Parallel(n_jobs=8)]: Done 12784 tasks      | elapsed: 35.8min
# [Parallel(n_jobs=8)]: Done 14434 tasks      | elapsed: 40.4min
# [Parallel(n_jobs=8)]: Done 15360 out of 15360 | elapsed: 42.8min finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('cvec',
#                                         CountVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biatha...
#                                                                     'nordic '
#                                                                     'combined', ...])),
#                                        ('rf', RandomForestClassifier())]),
#              n_jobs=8,
#              param_grid={'cvec__max_df': [0.9, 0.95],
#                          'cvec__max_features': [2000, 3000, 4000, 5000],
#                          'cvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'cvec__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                          'rf__max_depth': [2, 3],
#                          'rf__min_samples_leaf': [2, 3],
#                          'rf__min_samples_split': [5, 10],
#                          'rf__n_estimators': [1, 10, 100, 150]},
#              verbose=1)

# %%
# look at best parameters
rf_cvec.best_params_
# Out:
# {'cvec__max_df': 0.9,
#  'cvec__max_features': 4000,
#  'cvec__min_df': 0.01,
#  'cvec__ngram_range': (1, 3),
#  'rf__max_depth': 3,
#  'rf__min_samples_leaf': 2,
#  'rf__min_samples_split': 10,
#  'rf__n_estimators': 10}

# %%
# look at best scores
rf_cvec.best_score_
# Out:
# 0.797

# %%
# turn results into a dataframe
rf_cvec_results = pd.DataFrame(rf_cvec.cv_results_)

# %%
# look at GridSearch results
rf_cvec_results
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.600031      0.054853         0.111883        0.012515
# 1          0.561744      0.145415         0.129656        0.043682
# 2          1.722861      0.130101         0.320557        0.088325
# 3          1.941078      0.260816         0.173327        0.028260
# 4          0.851344      0.165864         0.086722        0.009844
# ...             ...           ...              ...             ...
# 3067       1.924121      0.021815         0.227204        0.009789
# 3068       0.862501      0.054534         0.150578        0.019656
# 3069       0.885078      0.038559         0.184718        0.029158
# 3070       1.585729      0.028994         0.218655        0.020277
# 3071       1.419292      0.343452         0.117604        0.016960
#
#      param_cvec__max_df param_cvec__max_features param_cvec__min_df  \
# 0                   0.9                     2000               0.01
# 1                   0.9                     2000               0.01
# 2                   0.9                     2000               0.01
# 3                   0.9                     2000               0.01
# 4                   0.9                     2000               0.01
# ...                 ...                      ...                ...
# 3067               0.95                     5000               0.05
# 3068               0.95                     5000               0.05
# 3069               0.95                     5000               0.05
# 3070               0.95                     5000               0.05
# 3071               0.95                     5000               0.05
#
#      param_cvec__ngram_range param_rf__max_depth param_rf__min_samples_leaf  \
# 0                     (1, 1)                   2                          2
# 1                     (1, 1)                   2                          2
# 2                     (1, 1)                   2                          2
# 3                     (1, 1)                   2                          2
# 4                     (1, 1)                   2                          2
# ...                      ...                 ...                        ...
# 3067                  (1, 3)                   3                          3
# 3068                  (1, 3)                   3                          3
# 3069                  (1, 3)                   3                          3
# 3070                  (1, 3)                   3                          3
# 3071                  (1, 3)                   3                          3
#
#      param_rf__min_samples_split param_rf__n_estimators  \
# 0                              5                      1
# 1                              5                     10
# 2                              5                    100
# 3                              5                    150
# 4                             10                      1
# ...                          ...                    ...
# 3067                           5                    150
# 3068                          10                      1
# 3069                          10                     10
# 3070                          10                    100
# 3071                          10                    150
#
#                                                  params  split0_test_score  \
# 0     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.589
# 1     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.687
# 2     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.747
# 3     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.727
# 4     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.565
# ...                                                 ...                ...
# 3067  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.696
# 3068  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.616
# 3069  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.682
# 3070  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.691
# 3071  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.715
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0                 0.561              0.587              0.565
# 1                 0.674              0.741              0.678
# 2                 0.705              0.707              0.725
# 3                 0.723              0.723              0.724
# 4                 0.586              0.570              0.603
# ...                 ...                ...                ...
# 3067              0.705              0.711              0.696
# 3068              0.620              0.647              0.603
# 3069              0.695              0.689              0.680
# 3070              0.714              0.713              0.699
# 3071              0.702              0.711              0.691
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 0.563           0.5730        0.012329             2965
# 1                 0.764           0.7088        0.036657             1072
# 2                 0.710           0.7188        0.015753              711
# 3                 0.732           0.7258        0.003429              504
# 4                 0.601           0.5850        0.015531             2831
# ...                 ...              ...             ...              ...
# 3067              0.745           0.7106        0.018117              997
# 3068              0.605           0.6182        0.015766             2455
# 3069              0.694           0.6880        0.006099             2000
# 3070              0.730           0.7094        0.013455             1055
# 3071              0.725           0.7088        0.011565             1075
#
# [3072 rows x 21 columns]

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
rf_cvec_results.groupby(['param_cvec__min_df'])['mean_test_score'].max()
# Out:
# param_cvec__min_df
# 0.010    0.7970
# 0.025    0.7418
# 0.030    0.7372
# 0.050    0.7160
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ### TFIDF Vectorizer

# %%
# set up Pipeline
rf2_pipe = Pipeline([
    ('tvec', TfidfVectorizer(stop_words = stop_words_list)),
    ('rf2', RandomForestClassifier())
])

# %%
# set parameters
rf2_pipe_params = {
    'tvec__max_features': [2000,3000,4000,5000],
    'tvec__min_df': [.01,.025,.03,.05],
    'tvec__max_df': [.9,.95],
    'tvec__ngram_range': [(1,1),(1,2),(1,3)],
    'rf2__n_estimators': [1,10,100,150],
    'rf2__max_depth': [2,3],
    'rf2__min_samples_split' : [5,10],
    'rf2__min_samples_leaf' : [2,3],
}

# %%
# set up GridSearch
rf_tvec = GridSearchCV(
    estimator = rf2_pipe,
    param_grid = rf2_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
rf_tvec.fit(X,y)
# Out:
# Fitting 5 folds for each of 3072 candidates, totalling 15360 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 1234 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=8)]: Done 1784 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=8)]: Done 2434 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=8)]: Done 3184 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=8)]: Done 4034 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=8)]: Done 4984 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=8)]: Done 6034 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=8)]: Done 7184 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=8)]: Done 8434 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=8)]: Done 9784 tasks      | elapsed: 26.0min
# [Parallel(n_jobs=8)]: Done 11234 tasks      | elapsed: 29.4min
# [Parallel(n_jobs=8)]: Done 12784 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=8)]: Done 14434 tasks      | elapsed: 37.0min
# [Parallel(n_jobs=8)]: Done 15360 out of 15360 | elapsed: 40.2min finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tvec',
#                                         TfidfVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biatha...
#                                                                     'combined', ...])),
#                                        ('rf2', RandomForestClassifier())]),
#              n_jobs=8,
#              param_grid={'rf2__max_depth': [2, 3],
#                          'rf2__min_samples_leaf': [2, 3],
#                          'rf2__min_samples_split': [5, 10],
#                          'rf2__n_estimators': [1, 10, 100, 150],
#                          'tvec__max_df': [0.9, 0.95],
#                          'tvec__max_features': [2000, 3000, 4000, 5000],
#                          'tvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'tvec__ngram_range': [(1, 1), (1, 2), (1, 3)]},
#              verbose=1)

# %%
# look at best parameters
rf_tvec.best_params_
# Out:
# {'rf2__max_depth': 3,
#  'rf2__min_samples_leaf': 2,
#  'rf2__min_samples_split': 5,
#  'rf2__n_estimators': 150,
#  'tvec__max_df': 0.9,
#  'tvec__max_features': 4000,
#  'tvec__min_df': 0.01,
#  'tvec__ngram_range': (1, 3)}

# %%
# look at best scores
rf_tvec.best_score_
# Out:
# 0.8037999999999998

# %%
# turn results into a dataframe
rf_tvec_results = pd.DataFrame(rf_tvec.cv_results_)

# %%
# look at GridSearch results
rf_tvec_results
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.283175      0.033318         0.094072        0.022195
# 1          0.568851      0.046015         0.115735        0.014306
# 2          0.770458      0.056365         0.226053        0.032433
# 3          0.328510      0.054916         0.086052        0.012517
# 4          0.717663      0.014147         0.118093        0.011064
# ...             ...           ...              ...             ...
# 3067       1.793322      0.036288         0.194465        0.017240
# 3068       1.836698      0.053852         0.250486        0.019130
# 3069       1.264007      0.041952         0.161310        0.011747
# 3070       1.565436      0.040171         0.183234        0.010499
# 3071       1.395108      0.228176         0.126929        0.027345
#
#      param_rf2__max_depth param_rf2__min_samples_leaf  \
# 0                       2                           2
# 1                       2                           2
# 2                       2                           2
# 3                       2                           2
# 4                       2                           2
# ...                   ...                         ...
# 3067                    3                           3
# 3068                    3                           3
# 3069                    3                           3
# 3070                    3                           3
# 3071                    3                           3
#
#      param_rf2__min_samples_split param_rf2__n_estimators param_tvec__max_df  \
# 0                               5                       1                0.9
# 1                               5                       1                0.9
# 2                               5                       1                0.9
# 3                               5                       1                0.9
# 4                               5                       1                0.9
# ...                           ...                     ...                ...
# 3067                           10                     150               0.95
# 3068                           10                     150               0.95
# 3069                           10                     150               0.95
# 3070                           10                     150               0.95
# 3071                           10                     150               0.95
#
#      param_tvec__max_features param_tvec__min_df param_tvec__ngram_range  \
# 0                        2000               0.01                  (1, 1)
# 1                        2000               0.01                  (1, 2)
# 2                        2000               0.01                  (1, 3)
# 3                        2000              0.025                  (1, 1)
# 4                        2000              0.025                  (1, 2)
# ...                       ...                ...                     ...
# 3067                     5000               0.03                  (1, 2)
# 3068                     5000               0.03                  (1, 3)
# 3069                     5000               0.05                  (1, 1)
# 3070                     5000               0.05                  (1, 2)
# 3071                     5000               0.05                  (1, 3)
#
#                                                  params  split0_test_score  \
# 0     {'rf2__max_depth': 2, 'rf2__min_samples_leaf':...              0.537
# 1     {'rf2__max_depth': 2, 'rf2__min_samples_leaf':...              0.605
# 2     {'rf2__max_depth': 2, 'rf2__min_samples_leaf':...              0.542
# 3     {'rf2__max_depth': 2, 'rf2__min_samples_leaf':...              0.588
# 4     {'rf2__max_depth': 2, 'rf2__min_samples_leaf':...              0.604
# ...                                                 ...                ...
# 3067  {'rf2__max_depth': 3, 'rf2__min_samples_leaf':...              0.761
# 3068  {'rf2__max_depth': 3, 'rf2__min_samples_leaf':...              0.756
# 3069  {'rf2__max_depth': 3, 'rf2__min_samples_leaf':...              0.722
# 3070  {'rf2__max_depth': 3, 'rf2__min_samples_leaf':...              0.699
# 3071  {'rf2__max_depth': 3, 'rf2__min_samples_leaf':...              0.701
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0                 0.594              0.605              0.583
# 1                 0.582              0.563              0.572
# 2                 0.544              0.544              0.556
# 3                 0.517              0.565              0.585
# 4                 0.629              0.543              0.580
# ...                 ...                ...                ...
# 3067              0.746              0.732              0.747
# 3068              0.748              0.745              0.747
# 3069              0.713              0.720              0.697
# 3070              0.716              0.719              0.694
# 3071              0.718              0.720              0.697
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 0.593           0.5824        0.023745             2779
# 1                 0.565           0.5774        0.015318             2848
# 2                 0.564           0.5500        0.008579             3059
# 3                 0.614           0.5738        0.032394             2897
# 4                 0.586           0.5884        0.028387             2706
# ...                 ...              ...             ...              ...
# 3067              0.755           0.7482        0.009786              534
# 3068              0.757           0.7506        0.004923              451
# 3069              0.740           0.7184        0.013923             1465
# 3070              0.738           0.7132        0.015664             1680
# 3071              0.741           0.7154        0.015679             1627
#
# [3072 rows x 21 columns]

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
rf_tvec_results.groupby(['param_tvec__min_df'])['mean_test_score'].max()
# Out:
# param_tvec__min_df
# 0.010    0.8038
# 0.025    0.7628
# 0.030    0.7564
# 0.050    0.7206
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ## Extra Trees
# ### Count Vectorizer

# %%
# set up Pipeline
et_pipe = Pipeline([
    ('cvec', CountVectorizer(stop_words = stop_words_list)),
    ('et', ExtraTreesClassifier())
])

# %%
# set parameters
et_pipe_params = {
    'cvec__max_features': [2000,3000,4000,5000],
    'cvec__min_df': [.01,.025,.03,.05],
    'cvec__max_df': [.9,.95],
    'cvec__ngram_range': [(1,1),(1,2),(1,3)],
    'et__n_estimators': [1,10,100,150],
    'et__max_depth': [2,3],
    'et__min_samples_split' : [5,10],
    'et__min_samples_leaf' : [2,3],
}

# %%
# set up GridSearch
et_cvec = GridSearchCV(
    estimator = et_pipe,
    param_grid = et_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
et_cvec.fit(X,y)
# Out:
# Fitting 5 folds for each of 3072 candidates, totalling 15360 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=8)]: Done 1234 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=8)]: Done 1784 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=8)]: Done 2434 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=8)]: Done 3184 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=8)]: Done 4034 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=8)]: Done 4984 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=8)]: Done 6034 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=8)]: Done 7184 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=8)]: Done 8434 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=8)]: Done 9784 tasks      | elapsed: 22.0min
# [Parallel(n_jobs=8)]: Done 11234 tasks      | elapsed: 25.2min
# [Parallel(n_jobs=8)]: Done 12784 tasks      | elapsed: 28.9min
# [Parallel(n_jobs=8)]: Done 14434 tasks      | elapsed: 33.0min
# [Parallel(n_jobs=8)]: Done 15360 out of 15360 | elapsed: 35.4min finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('cvec',
#                                         CountVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biatha...
#                                                                     'nordic '
#                                                                     'combined', ...])),
#                                        ('et', ExtraTreesClassifier())]),
#              n_jobs=8,
#              param_grid={'cvec__max_df': [0.9, 0.95],
#                          'cvec__max_features': [2000, 3000, 4000, 5000],
#                          'cvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'cvec__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                          'et__max_depth': [2, 3],
#                          'et__min_samples_leaf': [2, 3],
#                          'et__min_samples_split': [5, 10],
#                          'et__n_estimators': [1, 10, 100, 150]},
#              verbose=1)

# %%
# look at best parameters
et_cvec.best_params_
# Out:
# {'cvec__max_df': 0.95,
#  'cvec__max_features': 2000,
#  'cvec__min_df': 0.01,
#  'cvec__ngram_range': (1, 2),
#  'et__max_depth': 3,
#  'et__min_samples_leaf': 2,
#  'et__min_samples_split': 5,
#  'et__n_estimators': 10}

# %%
# look at best scores
et_cvec.best_score_
# Out:
# 0.7494

# %%
# turn results into a dataframe
et_cvec_results = pd.DataFrame(et_cvec.cv_results_)

# %%
# look at GridSearch results
et_cvec_results
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.254110      0.006674         0.077157        0.013529
# 1          0.336809      0.020749         0.068264        0.006297
# 2          0.689947      0.019545         0.133201        0.009663
# 3          1.001131      0.099487         0.189422        0.036121
# 4          0.310574      0.036335         0.084888        0.014396
# ...             ...           ...              ...             ...
# 3067       1.640853      0.034129         0.249728        0.015003
# 3068       0.873926      0.041328         0.171879        0.026215
# 3069       0.939318      0.013784         0.169082        0.015328
# 3070       1.342054      0.025337         0.241034        0.037359
# 3071       1.274552      0.266074         0.120907        0.019570
#
#      param_cvec__max_df param_cvec__max_features param_cvec__min_df  \
# 0                   0.9                     2000               0.01
# 1                   0.9                     2000               0.01
# 2                   0.9                     2000               0.01
# 3                   0.9                     2000               0.01
# 4                   0.9                     2000               0.01
# ...                 ...                      ...                ...
# 3067               0.95                     5000               0.05
# 3068               0.95                     5000               0.05
# 3069               0.95                     5000               0.05
# 3070               0.95                     5000               0.05
# 3071               0.95                     5000               0.05
#
#      param_cvec__ngram_range param_et__max_depth param_et__min_samples_leaf  \
# 0                     (1, 1)                   2                          2
# 1                     (1, 1)                   2                          2
# 2                     (1, 1)                   2                          2
# 3                     (1, 1)                   2                          2
# 4                     (1, 1)                   2                          2
# ...                      ...                 ...                        ...
# 3067                  (1, 3)                   3                          3
# 3068                  (1, 3)                   3                          3
# 3069                  (1, 3)                   3                          3
# 3070                  (1, 3)                   3                          3
# 3071                  (1, 3)                   3                          3
#
#      param_et__min_samples_split param_et__n_estimators  \
# 0                              5                      1
# 1                              5                     10
# 2                              5                    100
# 3                              5                    150
# 4                             10                      1
# ...                          ...                    ...
# 3067                           5                    150
# 3068                          10                      1
# 3069                          10                     10
# 3070                          10                    100
# 3071                          10                    150
#
#                                                  params  split0_test_score  \
# 0     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.566
# 1     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.724
# 2     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.710
# 3     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.671
# 4     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.544
# ...                                                 ...                ...
# 3067  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.707
# 3068  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.623
# 3069  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.689
# 3070  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.708
# 3071  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.710
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0                 0.560              0.542              0.544
# 1                 0.704              0.705              0.663
# 2                 0.637              0.710              0.628
# 3                 0.681              0.665              0.692
# 4                 0.564              0.583              0.565
# ...                 ...                ...                ...
# 3067              0.696              0.701              0.704
# 3068              0.602              0.639              0.635
# 3069              0.676              0.687              0.689
# 3070              0.688              0.703              0.688
# 3071              0.697              0.717              0.690
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 0.586           0.5596        0.016070             2996
# 1                 0.673           0.6938        0.022462             1054
# 2                 0.671           0.6712        0.034776             2111
# 3                 0.714           0.6846        0.017327             1627
# 4                 0.565           0.5642        0.012352             2946
# ...                 ...              ...             ...              ...
# 3067              0.741           0.7098        0.016017              273
# 3068              0.586           0.6170        0.020149             2326
# 3069              0.692           0.6866        0.005535             1509
# 3070              0.709           0.6992        0.009368              757
# 3071              0.732           0.7092        0.014824              289
#
# [3072 rows x 21 columns]

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
et_cvec_results.groupby(['param_cvec__min_df'])['mean_test_score'].max()
# Out:
# param_cvec__min_df
# 0.010    0.7494
# 0.025    0.7286
# 0.030    0.7188
# 0.050    0.7108
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ### TFIDF Vectorizer

# %%
# set up Pipeline
et2_pipe = Pipeline([
    ('tvec', TfidfVectorizer(stop_words = stop_words_list)),
    ('et2', ExtraTreesClassifier())
])

# %%
# set parameters
et2_pipe_params = {
    'tvec__max_features': [2000,3000,4000,5000],
    'tvec__min_df': [.01,.025,.03,.05],
    'tvec__max_df': [.9,.95],
    'tvec__ngram_range': [(1,1),(1,2),(1,3)],
    'et2__n_estimators': [1,10,100,150],
    'et2__max_depth': [2,3],
    'et2__min_samples_split' : [5,10],
    'et2__min_samples_leaf' : [2,3],
}

# %%
# set up GridSearch
et_tvec = GridSearchCV(
    estimator = et2_pipe,
    param_grid = et2_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
et_tvec.fit(X,y)
# Out:
# Fitting 5 folds for each of 3072 candidates, totalling 15360 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 1234 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=8)]: Done 1784 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=8)]: Done 2434 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=8)]: Done 3184 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=8)]: Done 4034 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=8)]: Done 4984 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=8)]: Done 6034 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=8)]: Done 7184 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=8)]: Done 8434 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=8)]: Done 9784 tasks      | elapsed: 24.9min
# [Parallel(n_jobs=8)]: Done 11234 tasks      | elapsed: 28.5min
# [Parallel(n_jobs=8)]: Done 12784 tasks      | elapsed: 31.9min
# [Parallel(n_jobs=8)]: Done 14434 tasks      | elapsed: 36.0min
# [Parallel(n_jobs=8)]: Done 15360 out of 15360 | elapsed: 39.5min finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tvec',
#                                         TfidfVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biatha...
#                                                                     'combined', ...])),
#                                        ('et2', ExtraTreesClassifier())]),
#              n_jobs=8,
#              param_grid={'et2__max_depth': [2, 3],
#                          'et2__min_samples_leaf': [2, 3],
#                          'et2__min_samples_split': [5, 10],
#                          'et2__n_estimators': [1, 10, 100, 150],
#                          'tvec__max_df': [0.9, 0.95],
#                          'tvec__max_features': [2000, 3000, 4000, 5000],
#                          'tvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'tvec__ngram_range': [(1, 1), (1, 2), (1, 3)]},
#              verbose=1)

# %%
# look at best parameters
et_tvec.best_params_
# Out:
# {'et2__max_depth': 3,
#  'et2__min_samples_leaf': 2,
#  'et2__min_samples_split': 10,
#  'et2__n_estimators': 100,
#  'tvec__max_df': 0.9,
#  'tvec__max_features': 3000,
#  'tvec__min_df': 0.025,
#  'tvec__ngram_range': (1, 3)}

# %%
# look at best scores
et_tvec.best_score_
# Out:
# 0.849

# %%
# turn results into a dataframe
et_tvec_results = pd.DataFrame(et_tvec.cv_results_)

# %%
# look at GridSearch results
et_tvec_results
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.305358      0.018060         0.093701        0.019869
# 1          0.666907      0.051332         0.174562        0.029000
# 2          0.995640      0.028999         0.184270        0.011430
# 3          0.363014      0.014386         0.076263        0.010371
# 4          0.696922      0.005256         0.143096        0.018979
# ...             ...           ...              ...             ...
# 3067       2.720122      0.047993         0.431921        0.058360
# 3068       2.999255      0.170747         0.409309        0.085454
# 3069       1.791256      0.060598         0.256971        0.060032
# 3070       1.901166      0.100059         0.243383        0.017336
# 3071       1.569272      0.315692         0.137785        0.019942
#
#      param_et2__max_depth param_et2__min_samples_leaf  \
# 0                       2                           2
# 1                       2                           2
# 2                       2                           2
# 3                       2                           2
# 4                       2                           2
# ...                   ...                         ...
# 3067                    3                           3
# 3068                    3                           3
# 3069                    3                           3
# 3070                    3                           3
# 3071                    3                           3
#
#      param_et2__min_samples_split param_et2__n_estimators param_tvec__max_df  \
# 0                               5                       1                0.9
# 1                               5                       1                0.9
# 2                               5                       1                0.9
# 3                               5                       1                0.9
# 4                               5                       1                0.9
# ...                           ...                     ...                ...
# 3067                           10                     150               0.95
# 3068                           10                     150               0.95
# 3069                           10                     150               0.95
# 3070                           10                     150               0.95
# 3071                           10                     150               0.95
#
#      param_tvec__max_features param_tvec__min_df param_tvec__ngram_range  \
# 0                        2000               0.01                  (1, 1)
# 1                        2000               0.01                  (1, 2)
# 2                        2000               0.01                  (1, 3)
# 3                        2000              0.025                  (1, 1)
# 4                        2000              0.025                  (1, 2)
# ...                       ...                ...                     ...
# 3067                     5000               0.03                  (1, 2)
# 3068                     5000               0.03                  (1, 3)
# 3069                     5000               0.05                  (1, 1)
# 3070                     5000               0.05                  (1, 2)
# 3071                     5000               0.05                  (1, 3)
#
#                                                  params  split0_test_score  \
# 0     {'et2__max_depth': 2, 'et2__min_samples_leaf':...              0.543
# 1     {'et2__max_depth': 2, 'et2__min_samples_leaf':...              0.544
# 2     {'et2__max_depth': 2, 'et2__min_samples_leaf':...              0.565
# 3     {'et2__max_depth': 2, 'et2__min_samples_leaf':...              0.522
# 4     {'et2__max_depth': 2, 'et2__min_samples_leaf':...              0.557
# ...                                                 ...                ...
# 3067  {'et2__max_depth': 3, 'et2__min_samples_leaf':...              0.756
# 3068  {'et2__max_depth': 3, 'et2__min_samples_leaf':...              0.778
# 3069  {'et2__max_depth': 3, 'et2__min_samples_leaf':...              0.718
# 3070  {'et2__max_depth': 3, 'et2__min_samples_leaf':...              0.720
# 3071  {'et2__max_depth': 3, 'et2__min_samples_leaf':...              0.714
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0                 0.600              0.543              0.544
# 1                 0.544              0.542              0.542
# 2                 0.542              0.559              0.552
# 3                 0.554              0.532              0.521
# 4                 0.512              0.522              0.542
# ...                 ...                ...                ...
# 3067              0.729              0.752              0.770
# 3068              0.755              0.727              0.773
# 3069              0.702              0.728              0.702
# 3070              0.705              0.711              0.700
# 3071              0.704              0.709              0.689
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 0.519           0.5498        0.026813             2873
# 1                 0.544           0.5432        0.000980             2980
# 2                 0.544           0.5524        0.008732             2831
# 3                 0.562           0.5382        0.016810             3047
# 4                 0.542           0.5350        0.016000             3061
# ...                 ...              ...             ...              ...
# 3067              0.755           0.7524        0.013245              586
# 3068              0.775           0.7616        0.019075              498
# 3069              0.740           0.7180        0.014805             1207
# 3070              0.734           0.7140        0.012017             1336
# 3071              0.738           0.7108        0.015967             1429
#
# [3072 rows x 21 columns]

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
et_tvec_results.groupby(['param_tvec__min_df'])['mean_test_score'].max()
# Out:
# param_tvec__min_df
# 0.010    0.7686
# 0.025    0.8490
# 0.030    0.7728
# 0.050    0.7276
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ## KNN
# ### Count Vectorizer

# %%
# set up Pipeline
knn_pipe = Pipeline([
    ('cvec', CountVectorizer(stop_words = stop_words_list)),
    ('knn', KNeighborsClassifier())
])

# %%
# set parameters
knn_pipe_params = {
    'cvec__max_features': [2000,3000,4000,5000],
    'cvec__min_df': [.01,.025,.03,.05],
    'cvec__max_df': [.9,.95],
    'cvec__ngram_range': [(1,1),(1,2),(1,3)],
    'knn__n_neighbors': [3,5,7,11,13,15],
    'knn__weights': ['uniform','distance']
}

# %%
# set up GridSearch
knn_cvec = GridSearchCV(
    estimator = knn_pipe,
    param_grid = knn_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
knn_cvec.fit(X,y)
# Out:
# Fitting 5 folds for each of 1152 candidates, totalling 5760 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=8)]: Done 1234 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=8)]: Done 1784 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=8)]: Done 2434 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=8)]: Done 3184 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=8)]: Done 4034 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=8)]: Done 4984 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=8)]: Done 5760 out of 5760 | elapsed: 14.4min finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('cvec',
#                                         CountVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biathalon',
#                                                                     'snowcross',
#                                                                     'surfing',
#                                                                     'apres-ski',
#                                                                     'nordic '
#                                                                     'combined', ...])),
#                                        ('knn', KNeighborsClassifier())]),
#              n_jobs=8,
#              param_grid={'cvec__max_df': [0.9, 0.95],
#                          'cvec__max_features': [2000, 3000, 4000, 5000],
#                          'cvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'cvec__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                          'knn__n_neighbors': [3, 5, 7, 11, 13, 15],
#                          'knn__weights': ['uniform', 'distance']},
#              verbose=1)

# %%
# look at best parameters
knn_cvec.best_params_
# Out:
# {'cvec__max_df': 0.9,
#  'cvec__max_features': 2000,
#  'cvec__min_df': 0.01,
#  'cvec__ngram_range': (1, 2),
#  'knn__n_neighbors': 5,
#  'knn__weights': 'distance'}

# %%
# look at best scores
knn_cvec.best_score_
# Out:
# 0.9932000000000001

# %%
# turn results into a dataframe
knn_cvec_results = pd.DataFrame(knn_cvec.cv_results_)

# %%
# look at GridSearch results
knn_cvec_results
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.341623      0.020337         0.569080        0.021018
# 1          0.359455      0.056687         0.323387        0.044332
# 2          0.388263      0.007887         0.738871        0.050034
# 3          0.427129      0.090365         0.440014        0.103213
# 4          0.328873      0.020642         0.526251        0.022762
# ...             ...           ...              ...             ...
# 1147       0.830622      0.034841         0.381560        0.018612
# 1148       0.806897      0.027294         0.550842        0.027333
# 1149       0.892591      0.067287         0.461259        0.034458
# 1150       0.933959      0.037494         0.561851        0.077796
# 1151       0.734661      0.108171         0.244944        0.051117
#
#      param_cvec__max_df param_cvec__max_features param_cvec__min_df  \
# 0                   0.9                     2000               0.01
# 1                   0.9                     2000               0.01
# 2                   0.9                     2000               0.01
# 3                   0.9                     2000               0.01
# 4                   0.9                     2000               0.01
# ...                 ...                      ...                ...
# 1147               0.95                     5000               0.05
# 1148               0.95                     5000               0.05
# 1149               0.95                     5000               0.05
# 1150               0.95                     5000               0.05
# 1151               0.95                     5000               0.05
#
#      param_cvec__ngram_range param_knn__n_neighbors param_knn__weights  \
# 0                     (1, 1)                      3            uniform
# 1                     (1, 1)                      3           distance
# 2                     (1, 1)                      5            uniform
# 3                     (1, 1)                      5           distance
# 4                     (1, 1)                      7            uniform
# ...                      ...                    ...                ...
# 1147                  (1, 3)                     11           distance
# 1148                  (1, 3)                     13            uniform
# 1149                  (1, 3)                     13           distance
# 1150                  (1, 3)                     15            uniform
# 1151                  (1, 3)                     15           distance
#
#                                                  params  split0_test_score  \
# 0     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.977
# 1     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.977
# 2     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.987
# 3     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.988
# 4     {'cvec__max_df': 0.9, 'cvec__max_features': 20...              0.986
# ...                                                 ...                ...
# 1147  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.821
# 1148  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.804
# 1149  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.811
# 1150  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.813
# 1151  {'cvec__max_df': 0.95, 'cvec__max_features': 5...              0.822
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0                 0.978              0.979              0.976
# 1                 0.978              0.979              0.976
# 2                 0.996              0.995              0.987
# 3                 0.996              0.995              0.987
# 4                 0.996              0.993              0.985
# ...                 ...                ...                ...
# 1147              0.813              0.827              0.785
# 1148              0.795              0.812              0.772
# 1149              0.811              0.825              0.783
# 1150              0.796              0.809              0.775
# 1151              0.809              0.824              0.783
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 0.978           0.9776        0.001020              241
# 1                 0.978           0.9776        0.001020              241
# 2                 0.997           0.9924        0.004454               49
# 3                 0.997           0.9926        0.004224               41
# 4                 0.997           0.9914        0.005004              161
# ...                 ...              ...             ...              ...
# 1147              0.825           0.8142        0.015367              865
# 1148              0.815           0.7996        0.015448             1081
# 1149              0.824           0.8108        0.015158              937
# 1150              0.811           0.8008        0.014204             1057
# 1151              0.820           0.8116        0.015213              913
#
# [1152 rows x 19 columns]

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
knn_cvec_results.groupby(['param_cvec__min_df'])['mean_test_score'].max()
# Out:
# param_cvec__min_df
# 0.010    0.9932
# 0.025    0.9342
# 0.030    0.8490
# 0.050    0.8194
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ### TFIDF Vectorizer

# %%
# set up Pipeline
knn2_pipe = Pipeline([
    ('tvec', TfidfVectorizer(stop_words = stop_words_list)),
    ('knn2', KNeighborsClassifier())
])

# %%
# set parameters
knn2_pipe_params = {
    'tvec__max_features': [2000,3000,4000,5000],
    'tvec__min_df': [.01,.025,.03,.05],
    'tvec__max_df': [.9,.95],
    'tvec__ngram_range': [(1,1),(1,2),(1,3)],
    'knn2__n_neighbors': [3,5,7,11,13,15],
    'knn2__weights': ['uniform','distance']
}

# %%
# set up GridSearch
knn_tvec = GridSearchCV(
    estimator = knn2_pipe,
    param_grid = knn2_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
knn_tvec.fit(X,y)
# Out:
# Fitting 5 folds for each of 1152 candidates, totalling 5760 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=8)]: Done 1234 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=8)]: Done 1784 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=8)]: Done 2434 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=8)]: Done 3184 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=8)]: Done 4034 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=8)]: Done 4984 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=8)]: Done 5760 out of 5760 | elapsed: 12.7min finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tvec',
#                                         TfidfVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biatha...,
#                                                                     'snowcross',
#                                                                     'surfing',
#                                                                     'apres-ski',
#                                                                     'nordic '
#                                                                     'combined', ...])),
#                                        ('knn2', KNeighborsClassifier())]),
#              n_jobs=8,
#              param_grid={'knn2__n_neighbors': [3, 5, 7, 11, 13, 15],
#                          'knn2__weights': ['uniform', 'distance'],
#                          'tvec__max_df': [0.9, 0.95],
#                          'tvec__max_features': [2000, 3000, 4000, 5000],
#                          'tvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'tvec__ngram_range': [(1, 1), (1, 2), (1, 3)]},
#              verbose=1)

# %%
# look at best parameters
knn_tvec.best_params_
# Out:
# {'knn2__n_neighbors': 5,
#  'knn2__weights': 'distance',
#  'tvec__max_df': 0.9,
#  'tvec__max_features': 2000,
#  'tvec__min_df': 0.01,
#  'tvec__ngram_range': (1, 3)}

# %%
# look at best scores
knn_tvec.best_score_
# Out:
# 0.9970000000000001

# %%
# turn results into a dataframe
knn_tvec_results = pd.DataFrame(knn_tvec.cv_results_)

# %%
# look at GridSearch results
knn_tvec_results
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.278811      0.013622         0.438160        0.016746
# 1          0.576534      0.028303         0.469361        0.033717
# 2          0.837742      0.035284         0.614030        0.028173
# 3          0.348913      0.041529         0.418483        0.011894
# 4          0.735007      0.034225         0.475090        0.053497
# ...             ...           ...              ...             ...
# 1147       0.561898      0.004916         0.378772        0.025297
# 1148       0.800253      0.020403         0.398526        0.019010
# 1149       0.285258      0.009434         0.304010        0.024618
# 1150       0.541307      0.021211         0.357811        0.039492
# 1151       0.688445      0.111797         0.240950        0.041679
#
#      param_knn2__n_neighbors param_knn2__weights param_tvec__max_df  \
# 0                          3             uniform                0.9
# 1                          3             uniform                0.9
# 2                          3             uniform                0.9
# 3                          3             uniform                0.9
# 4                          3             uniform                0.9
# ...                      ...                 ...                ...
# 1147                      15            distance               0.95
# 1148                      15            distance               0.95
# 1149                      15            distance               0.95
# 1150                      15            distance               0.95
# 1151                      15            distance               0.95
#
#      param_tvec__max_features param_tvec__min_df param_tvec__ngram_range  \
# 0                        2000               0.01                  (1, 1)
# 1                        2000               0.01                  (1, 2)
# 2                        2000               0.01                  (1, 3)
# 3                        2000              0.025                  (1, 1)
# 4                        2000              0.025                  (1, 2)
# ...                       ...                ...                     ...
# 1147                     5000               0.03                  (1, 2)
# 1148                     5000               0.03                  (1, 3)
# 1149                     5000               0.05                  (1, 1)
# 1150                     5000               0.05                  (1, 2)
# 1151                     5000               0.05                  (1, 3)
#
#                                                  params  split0_test_score  \
# 0     {'knn2__n_neighbors': 3, 'knn2__weights': 'uni...              0.977
# 1     {'knn2__n_neighbors': 3, 'knn2__weights': 'uni...              0.977
# 2     {'knn2__n_neighbors': 3, 'knn2__weights': 'uni...              0.977
# 3     {'knn2__n_neighbors': 3, 'knn2__weights': 'uni...              0.869
# 4     {'knn2__n_neighbors': 3, 'knn2__weights': 'uni...              0.869
# ...                                                 ...                ...
# 1147  {'knn2__n_neighbors': 15, 'knn2__weights': 'di...              0.842
# 1148  {'knn2__n_neighbors': 15, 'knn2__weights': 'di...              0.842
# 1149  {'knn2__n_neighbors': 15, 'knn2__weights': 'di...              0.734
# 1150  {'knn2__n_neighbors': 15, 'knn2__weights': 'di...              0.734
# 1151  {'knn2__n_neighbors': 15, 'knn2__weights': 'di...              0.734
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0                 0.975              0.978              0.977
# 1                 0.977              0.979              0.977
# 2                 0.978              0.979              0.977
# 3                 0.861              0.845              0.862
# 4                 0.862              0.845              0.862
# ...                 ...                ...                ...
# 1147              0.865              0.857              0.849
# 1148              0.865              0.857              0.849
# 1149              0.747              0.829              0.791
# 1150              0.747              0.829              0.791
# 1151              0.747              0.829              0.791
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 0.975           0.9764        0.001200              273
# 1                 0.975           0.9770        0.001265              257
# 2                 0.976           0.9774        0.001020              241
# 3                 0.865           0.8604        0.008188              561
# 4                 0.865           0.8606        0.008212              529
# ...                 ...              ...             ...              ...
# 1147              0.854           0.8534        0.007710              657
# 1148              0.854           0.8534        0.007710              657
# 1149              0.831           0.7864        0.040307              985
# 1150              0.831           0.7864        0.040307              985
# 1151              0.831           0.7864        0.040307              985
#
# [1152 rows x 19 columns]

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
knn_tvec_results.groupby(['param_tvec__min_df'])['mean_test_score'].max()
# Out:
# param_tvec__min_df
# 0.010    0.9970
# 0.025    0.9478
# 0.030    0.8582
# 0.050    0.8046
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ## Logr w/ Lasso and Ridge
# ### Count Vectorizer

# %%
# set up Pipeline
logr_pipe = Pipeline([
    ('cvec', CountVectorizer(stop_words = stop_words_list)),
    ('logr', LogisticRegression())
])

# %%
# set parameters
logr_pipe_params = {
    'cvec__max_features': [2000,3000,4000,5000],
    'cvec__min_df': [.01,.025,.03,.05],
    'cvec__max_df': [.9,.95], 
    'cvec__ngram_range': [(1,1),(1,2),(1,3)],
    'logr__penalty': ['l1','l2'],
    'logr__C': [.1,1,3,5,10,15],
    'logr__solver': ['lbfgs','liblinear']
}

# %%
# set up GridSearch
logr_cvec = GridSearchCV(
    estimator = logr_pipe,
    param_grid = logr_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
logr_cvec.fit(X,y)
# Out:
# Fitting 5 folds for each of 2304 candidates, totalling 11520 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 1234 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=8)]: Done 1784 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=8)]: Done 2434 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=8)]: Done 3184 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=8)]: Done 4034 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=8)]: Done 4984 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=8)]: Done 6034 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=8)]: Done 7184 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=8)]: Done 8434 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=8)]: Done 9784 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=8)]: Done 11234 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=8)]: Done 11520 out of 11520 | elapsed: 13.8min finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('cvec',
#                                         CountVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biatha...
#                                                                     'surfing',
#                                                                     'apres-ski',
#                                                                     'nordic '
#                                                                     'combined', ...])),
#                                        ('logr', LogisticRegression())]),
#              n_jobs=8,
#              param_grid={'cvec__max_df': [0.9, 0.95],
#                          'cvec__max_features': [2000, 3000, 4000, 5000],
#                          'cvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'cvec__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                          'logr__C': [0.1, 1, 3, 5, 10, 15],
#                          'logr__penalty': ['l1', 'l2'],
#                          'logr__solver': ['lbfgs', 'liblinear']},
#              verbose=1)

# %%
# look at best parameters
logr_cvec.best_params_
# Out:
# {'cvec__max_df': 0.9,
#  'cvec__max_features': 2000,
#  'cvec__min_df': 0.01,
#  'cvec__ngram_range': (1, 3),
#  'logr__C': 0.1,
#  'logr__penalty': 'l2',
#  'logr__solver': 'lbfgs'}

# %%
# look at best scores
logr_cvec.best_score_
# Out:
# 0.9955999999999999

# %%
# turn results into a dataframe
logr_cvec_results = pd.DataFrame(logr_cvec.cv_results_)

# %%
# look at GridSearch results
logr_cvec_results
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.348518      0.084127         0.000000        0.000000
# 1          0.461195      0.090982         0.121779        0.042644
# 2          0.532126      0.036775         0.089138        0.020677
# 3          0.418752      0.025962         0.086550        0.018390
# 4          0.398341      0.019313         0.000000        0.000000
# ...             ...           ...              ...             ...
# 2299       0.471399      0.008049         0.090957        0.008469
# 2300       0.455047      0.019677         0.000000        0.000000
# 2301       0.476844      0.007637         0.093503        0.010650
# 2302       0.544405      0.009401         0.095318        0.020078
# 2303       0.464059      0.036473         0.058216        0.007259
#
#      param_cvec__max_df param_cvec__max_features param_cvec__min_df  \
# 0                   0.9                     2000               0.01
# 1                   0.9                     2000               0.01
# 2                   0.9                     2000               0.01
# 3                   0.9                     2000               0.01
# 4                   0.9                     2000               0.01
# ...                 ...                      ...                ...
# 2299               0.95                     5000               0.05
# 2300               0.95                     5000               0.05
# 2301               0.95                     5000               0.05
# 2302               0.95                     5000               0.05
# 2303               0.95                     5000               0.05
#
#      param_cvec__ngram_range param_logr__C param_logr__penalty  \
# 0                     (1, 1)           0.1                  l1
# 1                     (1, 1)           0.1                  l1
# 2                     (1, 1)           0.1                  l2
# 3                     (1, 1)           0.1                  l2
# 4                     (1, 1)             1                  l1
# ...                      ...           ...                 ...
# 2299                  (1, 3)            10                  l2
# 2300                  (1, 3)            15                  l1
# 2301                  (1, 3)            15                  l1
# 2302                  (1, 3)            15                  l2
# 2303                  (1, 3)            15                  l2
#
#      param_logr__solver                                             params  \
# 0                 lbfgs  {'cvec__max_df': 0.9, 'cvec__max_features': 20...
# 1             liblinear  {'cvec__max_df': 0.9, 'cvec__max_features': 20...
# 2                 lbfgs  {'cvec__max_df': 0.9, 'cvec__max_features': 20...
# 3             liblinear  {'cvec__max_df': 0.9, 'cvec__max_features': 20...
# 4                 lbfgs  {'cvec__max_df': 0.9, 'cvec__max_features': 20...
# ...                 ...                                                ...
# 2299          liblinear  {'cvec__max_df': 0.95, 'cvec__max_features': 5...
# 2300              lbfgs  {'cvec__max_df': 0.95, 'cvec__max_features': 5...
# 2301          liblinear  {'cvec__max_df': 0.95, 'cvec__max_features': 5...
# 2302              lbfgs  {'cvec__max_df': 0.95, 'cvec__max_features': 5...
# 2303          liblinear  {'cvec__max_df': 0.95, 'cvec__max_features': 5...
#
#       split0_test_score  split1_test_score  split2_test_score  \
# 0                   NaN                NaN                NaN
# 1                 0.977              0.974              0.971
# 2                 0.984              0.984              0.991
# 3                 0.984              0.984              0.991
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 2299              0.747              0.701              0.723
# 2300                NaN                NaN                NaN
# 2301              0.747              0.701              0.723
# 2302              0.747              0.701              0.723
# 2303              0.747              0.701              0.723
#
#       split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0                   NaN                NaN              NaN             NaN
# 1                 0.977              0.985           0.9768        0.004665
# 2                 0.985              0.996           0.9880        0.004775
# 3                 0.985              0.996           0.9880        0.004775
# 4                   NaN                NaN              NaN             NaN
# ...                 ...                ...              ...             ...
# 2299              0.727              0.777           0.7350        0.025581
# 2300                NaN                NaN              NaN             NaN
# 2301              0.727              0.777           0.7350        0.025581
# 2302              0.727              0.777           0.7350        0.025581
# 2303              0.727              0.777           0.7350        0.025581
#
#       rank_test_score
# 0                2304
# 1                 427
# 2                 385
# 3                 385
# 4                1807
# ...               ...
# 2299             1465
# 2300             1806
# 2301             1465
# 2302             1465
# 2303             1465
#
# [2304 rows x 20 columns]

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
logr_cvec_results.groupby(['param_cvec__min_df'])['mean_test_score'].max()
# Out:
# param_cvec__min_df
# 0.010    0.9956
# 0.025    0.9382
# 0.030    0.8376
# 0.050    0.7354
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ### TFIDF Vectorizer

# %%
# set up Pipeline
logr2_pipe = Pipeline([
    ('tvec', TfidfVectorizer(stop_words = stop_words_list)),
    ('logr2', LogisticRegression())
])

# %%
# set parameters
logr2_pipe_params = {
    'tvec__max_features': [2000,3000,4000,5000],
    'tvec__min_df': [.01,.025,.03,.05],
    'tvec__max_df': [.9,.95],
    'tvec__ngram_range': [(1,1),(1,2),(1,3)],
    'logr2__penalty': ['l1','l2'],
    'logr2__C': [.1,1,3,5,10,15],
    'logr2__solver': ['lbfgs','liblinear']
}

# %%
# set up GridSearch
logr_tvec = GridSearchCV(
    estimator = logr2_pipe,
    param_grid = logr2_pipe_params,
    cv = 5,
    verbose = 1,
    n_jobs = 8
)

# %%
# fit GridSearch
logr_tvec.fit(X,y)
# Out:
# Fitting 5 folds for each of 2304 candidates, totalling 11520 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=8)]: Done 722 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=8)]: Done 1072 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=8)]: Done 1522 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 2072 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=8)]: Done 2722 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=8)]: Done 3472 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=8)]: Done 4322 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=8)]: Done 5272 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=8)]: Done 6322 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=8)]: Done 7472 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=8)]: Done 8722 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=8)]: Done 10072 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=8)]: Done 11520 out of 11520 | elapsed: 10.5min finished
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['apres', 'combined', 'country', 'heli', 'jumping', 'nordic', 'speed'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tvec',
#                                         TfidfVectorizer(stop_words=['ski',
#                                                                     'skiing',
#                                                                     'board',
#                                                                     'snowboard',
#                                                                     'snowboarding',
#                                                                     'boarding',
#                                                                     'skiers',
#                                                                     'snowboarders',
#                                                                     'snowboarder',
#                                                                     'skier',
#                                                                     'skis',
#                                                                     'boards',
#                                                                     'snowboards',
#                                                                     'www',
#                                                                     'https',
#                                                                     'com',
#                                                                     'splitboard',
#                                                                     'luge',
#                                                                     'heliskiing',
#                                                                     'downhill',
#                                                                     'heli-skiing',
#                                                                     'downhill',
#                                                                     'cross-country',
#                                                                     'surf',
#                                                                     'crosscountry',
#                                                                     'biatha...
#                                                                     'surfing',
#                                                                     'apres-ski',
#                                                                     'nordic '
#                                                                     'combined', ...])),
#                                        ('logr2', LogisticRegression())]),
#              n_jobs=8,
#              param_grid={'logr2__C': [0.1, 1, 3, 5, 10, 15],
#                          'logr2__penalty': ['l1', 'l2'],
#                          'logr2__solver': ['lbfgs', 'liblinear'],
#                          'tvec__max_df': [0.9, 0.95],
#                          'tvec__max_features': [2000, 3000, 4000, 5000],
#                          'tvec__min_df': [0.01, 0.025, 0.03, 0.05],
#                          'tvec__ngram_range': [(1, 1), (1, 2), (1, 3)]},
#              verbose=1)

# %%
# look at best parameters
logr_tvec.best_params_
# Out:
# {'logr2__C': 15,
#  'logr2__penalty': 'l2',
#  'logr2__solver': 'lbfgs',
#  'tvec__max_df': 0.9,
#  'tvec__max_features': 2000,
#  'tvec__min_df': 0.01,
#  'tvec__ngram_range': (1, 2)}

# %%
# look at best scores
logr_tvec.best_score_
# Out:
# 0.9973999999999998

# %%
# turn results into a dataframe
logr_tvec_results = pd.DataFrame(logr_tvec.cv_results_)

# %%
# look at GridSearch results
logr_tvec_results
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.119576      0.015904         0.000000        0.000000
# 1          0.275877      0.003226         0.000000        0.000000
# 2          0.408868      0.008387         0.000000        0.000000
# 3          0.150401      0.005080         0.000000        0.000000
# 4          0.326332      0.020459         0.000000        0.000000
# ...             ...           ...              ...             ...
# 2299       0.382222      0.012210         0.078600        0.002851
# 2300       0.553954      0.009009         0.099866        0.011217
# 2301       0.196838      0.006841         0.040637        0.010245
# 2302       0.332843      0.014928         0.057716        0.006864
# 2303       0.363054      0.045386         0.050970        0.004230
#
#      param_logr2__C param_logr2__penalty param_logr2__solver  \
# 0               0.1                   l1               lbfgs
# 1               0.1                   l1               lbfgs
# 2               0.1                   l1               lbfgs
# 3               0.1                   l1               lbfgs
# 4               0.1                   l1               lbfgs
# ...             ...                  ...                 ...
# 2299             15                   l2           liblinear
# 2300             15                   l2           liblinear
# 2301             15                   l2           liblinear
# 2302             15                   l2           liblinear
# 2303             15                   l2           liblinear
#
#      param_tvec__max_df param_tvec__max_features param_tvec__min_df  \
# 0                   0.9                     2000               0.01
# 1                   0.9                     2000               0.01
# 2                   0.9                     2000               0.01
# 3                   0.9                     2000              0.025
# 4                   0.9                     2000              0.025
# ...                 ...                      ...                ...
# 2299               0.95                     5000               0.03
# 2300               0.95                     5000               0.03
# 2301               0.95                     5000               0.05
# 2302               0.95                     5000               0.05
# 2303               0.95                     5000               0.05
#
#      param_tvec__ngram_range  \
# 0                     (1, 1)
# 1                     (1, 2)
# 2                     (1, 3)
# 3                     (1, 1)
# 4                     (1, 2)
# ...                      ...
# 2299                  (1, 2)
# 2300                  (1, 3)
# 2301                  (1, 1)
# 2302                  (1, 2)
# 2303                  (1, 3)
#
#                                                  params  split0_test_score  \
# 0     {'logr2__C': 0.1, 'logr2__penalty': 'l1', 'log...                NaN
# 1     {'logr2__C': 0.1, 'logr2__penalty': 'l1', 'log...                NaN
# 2     {'logr2__C': 0.1, 'logr2__penalty': 'l1', 'log...                NaN
# 3     {'logr2__C': 0.1, 'logr2__penalty': 'l1', 'log...                NaN
# 4     {'logr2__C': 0.1, 'logr2__penalty': 'l1', 'log...                NaN
# ...                                                 ...                ...
# 2299  {'logr2__C': 15, 'logr2__penalty': 'l2', 'logr...              0.818
# 2300  {'logr2__C': 15, 'logr2__penalty': 'l2', 'logr...              0.818
# 2301  {'logr2__C': 15, 'logr2__penalty': 'l2', 'logr...              0.779
# 2302  {'logr2__C': 15, 'logr2__penalty': 'l2', 'logr...              0.779
# 2303  {'logr2__C': 15, 'logr2__penalty': 'l2', 'logr...              0.779
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 2299              0.831              0.844              0.826
# 2300              0.831              0.844              0.826
# 2301              0.742              0.750              0.730
# 2302              0.742              0.750              0.730
# 2303              0.742              0.750              0.730
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                   NaN              NaN             NaN             2304
# 1                   NaN              NaN             NaN             1867
# 2                   NaN              NaN             NaN             1866
# 3                   NaN              NaN             NaN             1865
# 4                   NaN              NaN             NaN             1864
# ...                 ...              ...             ...              ...
# 2299              0.821           0.8280        0.009143              961
# 2300              0.821           0.8280        0.009143              961
# 2301              0.793           0.7588        0.023524             1393
# 2302              0.793           0.7588        0.023524             1393
# 2303              0.793           0.7588        0.023524             1393
#
# [2304 rows x 20 columns]

# %%
# realizing that min df played the largest role in model scores,
# i wanted to quantify exactly how much of a difference it made
logr_tvec_results.groupby(['param_tvec__min_df'])['mean_test_score'].max()
# Out:
# param_tvec__min_df
# 0.010    0.9974
# 0.025    0.9352
# 0.030    0.8350
# 0.050    0.7606
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ## Important Coefficients

# %% [markdown]
# Created a dataframe to see the words with the highest impact on the model, as well as to make sure that none of them were specific only to skiing or snowboarding.  If they were then I added them to the stopwordlist and reran all of the code.

# %%
# create a dataframe of coefficients
coefs = pd.DataFrame(np.exp(logr_cvec.best_estimator_[1].coef_[0]))

# %%
# add a column that shows the coefficient
coefs['comment'] = logr_cvec.best_estimator_[0].get_feature_names()

# %%
# sort coefficients (looked at both ascending = True and False)
coefs.sort_values(by = 0, ascending = True).head(60)
# Out:
#              0                comment
# 368   0.054285                 confus
# 980   0.071157                   said
# 561   0.076917                   haha
# 740   0.162578               mean way
# 546   0.176904          good backflip
# 197   0.200386               backflip
# 1053  0.256757                solitud
# 1165  0.256757          upper solitud
# 1164  0.300190                  upper
# 739   0.355754                   mean
# 862   0.427022               pic noob
# 1019  0.427022          shit pic noob
# 1018  0.427022               shit pic
# 390   0.444684     coverag fine trail
# 389   0.444684           coverag fine
# 499   0.444684             fine trail
# 801   0.451053                   noob
# 388   0.453007                coverag
# 1147  0.476959                  trail
# 1191  0.480183                    way
# 861   0.534387                    pic
# 1198  0.538509                   went
# 857   0.543587                  photo
# 498   0.587067                   fine
# 680   0.607496            like filter
# 1128  0.607496             thank like
# 704   0.607496       longer life seen
# 496   0.607496          filter longer
# 497   0.607496     filter longer life
# 681   0.607496     like filter longer
# 1129  0.607496      thank like filter
# 703   0.607496            longer life
# 667   0.617414              life seen
# 1199  0.623187            went abasin
# 1200  0.623187    went abasin instead
# 140   0.623187    abasin instead line
# 569   0.623187      happi went abasin
# 626   0.623187           instead line
# 568   0.623187             happi went
# 139   0.623187         abasin instead
# 1017  0.626522                   shit
# 138   0.632332                 abasin
# 702   0.641761                 longer
# 16    0.656184                    115
# 495   0.656545                 filter
# 212   0.657975  beacon honestli wrong
# 211   0.657975        beacon honestli
# 866   0.657975                   piep
# 1156  0.657975    tri beacon honestli
# 1155  0.657975             tri beacon
# 600   0.657975         honestli wrong
# 601   0.657975    honestli wrong piep
# 1123  0.657975        test tri beacon
# 1122  0.657975               test tri
# 1228  0.657975             wrong piep
# 210   0.657975                 beacon
# 280   0.684744                  break
# 565   0.696678                  happi
# 1005  0.706726                   seen
# 858   0.707305          photo equival

# %% [markdown]
# ## Sentiment Analysis

# %%
# display skiing sentiment scores
ski['sentiment'].value_counts()
# Out:
#  0    1414
#  1     869
# -1     217
# Name: sentiment, dtype: int64

# %%
# display snowboarding sentiment scores
sb['sentiment'].value_counts()
# Out:
#  0    1435
#  1     871
# -1     194
# Name: sentiment, dtype: int64

# %% [markdown]
# ## Confusion Matrix of Best Model

# %%
# print out classification metrics for analysis
model_confusion_matrix(knn_tvec,X,y)
# Out:
# True Positives: 2497
# True Negatives: 2500
# False Positives: 0
# False Negatives: 3
#
# Accuracy: 0.9994
# Misclassification Rate: 0.0006000000000000449
# Precision: 1.0
# Recall: 0.9988
# Specificity: 1.0

# %% [markdown]
# ## Saving Best Model Results

# %%
# pull the top score from each model
nb_cvec_model_scores = nb_cvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()
nb_tvec_model_scores = nb_tvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()
rf_cvec_model_scores = rf_cvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()
rf_tvec_model_scores = rf_tvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()
et_cvec_model_scores = et_cvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()
et_tvec_model_scores = et_tvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()
knn_cvec_model_scores = knn_cvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()
knn_tvec_model_scores = knn_tvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()
logr_cvec_model_scores = logr_cvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()
logr_tvec_model_scores = logr_tvec_results.sort_values('mean_test_score',ascending = False).head(1).filter(regex = r'split\d*_test_score').transpose()

# %%
# label each model
nb_cvec_model_scores.columns = ['nb cvec']
nb_tvec_model_scores.columns = ['nb tvec']
rf_cvec_model_scores.columns = ['rf cvec']
rf_tvec_model_scores.columns = ['rf tvec']
et_cvec_model_scores.columns = ['et cvec']
et_tvec_model_scores.columns = ['et tvec']
knn_cvec_model_scores.columns = ['knn cvec']
knn_tvec_model_scores.columns = ['knn tvec']
logr_cvec_model_scores.columns = ['logr cvec']
logr_tvec_model_scores.columns = ['logr tvec']

# %%
# create a dataframe of the top models scores
best_tests_2500_comments = pd.concat([nb_cvec_model_scores,nb_tvec_model_scores,
                        rf_cvec_model_scores,rf_tvec_model_scores,
                        et_cvec_model_scores,et_tvec_model_scores,
                        knn_cvec_model_scores,knn_tvec_model_scores,
                        logr_cvec_model_scores,logr_tvec_model_scores],axis = 1)

# %%
best_tests_2500_comments
# Out:
#                    nb cvec  nb tvec  rf cvec  rf tvec  et cvec  et tvec  \
# split0_test_score    0.869    0.910    0.739    0.805    0.783    0.904
# split1_test_score    0.873    0.912    0.764    0.804    0.733    0.820
# split2_test_score    0.880    0.926    0.777    0.759    0.726    0.838
# split3_test_score    0.893    0.934    0.838    0.825    0.752    0.797
# split4_test_score    0.880    0.926    0.867    0.826    0.753    0.886
#
#                    knn cvec  knn tvec  logr cvec  logr tvec
# split0_test_score     0.991     0.996      0.994      0.996
# split1_test_score     0.995     0.999      0.998      0.998
# split2_test_score     0.995     1.000      0.998      1.000
# split3_test_score     0.987     0.993      0.989      0.994
# split4_test_score     0.998     0.997      0.999      0.999

# %%
# save top model scores
best_tests_2500_comments.to_csv('./data/best_tests_2500_comments.csv')
